# %%
# !PYTHONPATH=.. python ../src/train/start_train.py  --hparams ../config/config.yaml
# Out:
# Training started
# ...
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 14.48it/s]
# 0 * Epoch (train):  15958.655537923178
# 100%|█████████████████████████████████████████| 400/400 [00:16<00:00, 24.82it/s]
# 0 * Epoch (valid):  5800.3972204589845
# ...
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.71it/s]
# 1 * Epoch (train):  82.68330144882202
# 100%|█████████████████████████████████████████| 400/400 [00:22<00:00, 18.18it/s]
# 1 * Epoch (valid):  67.38304025650024
# ...
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  6.65it/s]
# 2 * Epoch (train):  68.195631980896
# 100%|█████████████████████████████████████████| 400/400 [00:23<00:00, 16.97it/s]
# 2 * Epoch (valid):  63.037967405319215
# ...
# 100%|███████████████████████████████████████████| 24/24 [00:02<00:00,  8.55it/s]
# 3 * Epoch (train):  59.69116600354513
# 100%|█████████████████████████████████████████| 400/400 [00:23<00:00, 21.42it/s]
# ...
